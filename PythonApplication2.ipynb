# %%
import os.path

with open('uszkodzenia.txt') as f:
  my_list = [x.rstrip() for x in f]
# print(my_list)
var1, var2, var3, var11, var12, var13, var21, var22, var23, var31, var32, var33, var41, var42 ,var43, var51, var52, var53 = my_list;

# jesli nie ma raportu zrob zerowy
file_exists = os.path.exists('raport.txt')
if (file_exists == 0):
    fh = open('raport.txt')
    for i in range(8):
        fh.write('0 \n')
    fh.close()

# mozliwosc wykonania przegladu do wyzerowania uszkodzen
przeglad_globalny = 0
if (przeglad_globalny == 1):
    fh = open('raport.txt', 'w')
    for i in range(8):
        fh.write('0 \n')
    fh.close()


with open('raport.txt') as f:
  my_list_R = [x.rstrip() for x in f]
# warunki poczatkowe z poprzedniego raportu
Przekladnia_uszkodzona_R, Silnik_uszkodzony_R, Czujniki_uszkodzone_R, Utrata_szczelnosci_R, Uszkodzenie_silownika_R, Uszkodzone_sterowanie_lub_lacze_R, Wozek_uszkodzony_R, Podnosnik_uszkodzony_R = my_list_R;


#jesli uszkodzenie bylo w raporcie zwieksza sie jego wartosc:

Przekladnia_uszkodzona = int(Przekladnia_uszkodzona_R);
if (Przekladnia_uszkodzona > 20):
    Przekladnia_uszkodzona = Przekladnia_uszkodzona+5
Silnik_uszkodzony = int(Silnik_uszkodzony_R);

if (Silnik_uszkodzony > 20):
    Silnik_uszkodzony = Silnik_uszkodzony+5
Czujniki_uszkodzone = int(Czujniki_uszkodzone_R);

if (Czujniki_uszkodzone > 20):
    Czujniki_uszkodzone = Czujniki_uszkodzone+5             #wozek
    #-------------------------------------------------------------------------
Utrata_szczelnosci = int(Utrata_szczelnosci_R);             #podnosnik
if (Utrata_szczelnosci > 20):
    Utrata_szczelnosci = Utrata_szczelnosci+5

Uszkodzenie_silownika = int(Uszkodzenie_silownika_R);
if (Uszkodzenie_silownika > 20):
    Uszkodzenie_silownika = Uszkodzenie_silownika+5

Uszkodzone_sterowanie_lub_lacze = int(Uszkodzone_sterowanie_lub_lacze_R);
if (Uszkodzone_sterowanie_lub_lacze > 20):
    Uszkodzone_sterowanie_lub_lacze = Uszkodzone_sterowanie_lub_lacze+5

Wozek_uszkodzony = int(Wozek_uszkodzony_R);
Podnosnik_uszkodzony= int(Podnosnik_uszkodzony_R);
#::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# Przypisanie wag
#::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# Wózek transportowy
#przek³adania - urz¹dzenie steruj¹ce..................................................................1
if(var1 == "1"): # dryft czujnika
    Przekladnia_uszkodzona = Przekladnia_uszkodzona +8

if(var2 == "1"): # uszkodzenie zêba przek³adni
    Przekladnia_uszkodzona = Przekladnia_uszkodzona +7

if(var3 == "1"): # zu¿ycie wa³u
    Przekladnia_uszkodzona = Przekladnia_uszkodzona +9

print(Przekladnia_uszkodzona)

#silnik - urz¹dzenie wykonawcze..................................................................2
if(var11 == "1"): # zlobki rdzenia stojana
    Silnik_uszkodzony = Silnik_uszkodzony +6

if(var12 == "1"): # uszkodzenie uzwojenia
    Silnik_uszkodzony = Silnik_uszkodzony +8

if(var13 == "1"): # zu¿ycie wa³u wirnika
    Silnik_uszkodzony = Silnik_uszkodzony +7

print(Silnik_uszkodzony)

#czujniki - urz¹dzenia pomocnicze..................................................................3
if(var21 == "1"): # z³a pozycja
    Czujniki_uszkodzone = Czujniki_uszkodzone +6

if(var22 == "1"): # brak sygna³u
    Czujniki_uszkodzone = Czujniki_uszkodzone +10

if(var23 == "1"): # za du¿a delta
    Czujniki_uszkodzone = Czujniki_uszkodzone +7

print(Czujniki_uszkodzone)
#------------------------------------------------------------------------------------------------------------------------------------
# podnonik hydrauliczny...................................................................1
if(var31 == "1"): # wyciek zewnetrzny
    Utrata_szczelnosci = Utrata_szczelnosci +9

if(var32 == "1"): # wyciek wewnetrzny
    Utrata_szczelnosci = Utrata_szczelnosci +5

if(var33 == "1"): # zu¿ycie uszczelki
    Utrata_szczelnosci = Utrata_szczelnosci +3

print(Utrata_szczelnosci)

# podnonik hydrauliczny...................................................................2
if(var41 == "1"): # Wygiêty trzon
    Uszkodzenie_silownika = Uszkodzenie_silownika +4

if(var42 == "1"): # Niepe³ny zakres ruchowy
    Uszkodzenie_silownika = Uszkodzenie_silownika +7

if(var43 == "1"): # Brak ruchu
    Uszkodzenie_silownika = Uszkodzenie_silownika +9

print(Uszkodzenie_silownika)

# podnonik hydrauliczny...................................................................3
if(var51 == "1"): # Mniejszy sygna³ steruj¹cy
    Uszkodzone_sterowanie_lub_lacze = Uszkodzone_sterowanie_lub_lacze +7

if(var52 == "1"): # Brak sygna³u steruj¹cego
    Uszkodzone_sterowanie_lub_lacze = Uszkodzone_sterowanie_lub_lacze +12

if(var53 == "1"): # Niewidoczne urz¹dzenie
    Uszkodzone_sterowanie_lub_lacze = Uszkodzone_sterowanie_lub_lacze +9

print(Uszkodzone_sterowanie_lub_lacze)

#::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# Okrelanie stopnia uszkodzeñ
#::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::

#suma wag dla wozka
Wozek_uszkodzony =Przekladnia_uszkodzona+Silnik_uszkodzony+Czujniki_uszkodzone;
#suma wag dla podnosnika
Podnosnik_uszkodzony =Utrata_szczelnosci+Uszkodzenie_silownika+Uszkodzone_sterowanie_lub_lacze;
#::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# Wnioskowanie
#::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::

if (Wozek_uszkodzony == 0):
    print("Wozek jest w szczytowej formie")
    RaportW = 0;

if (Wozek_uszkodzony <= 10) and (Wozek_uszkodzony>0):
    print("Wozek nie wymaga przegladu")
    RaportW = 1;

if (Wozek_uszkodzony <= 20) and (Wozek_uszkodzony>10):
    print("Wozek ma zalecany przeglad")
    RaportW = 2;

if (Wozek_uszkodzony <= 30) and (Wozek_uszkodzony>20):
    print("Wozek wymaga przegladu")
    RaportW = 3;

if (Wozek_uszkodzony > 30):
    print("Wozek wymaga naprawy")
    RaportW = 4;
    #---------------------------------------------------------------------------------------------------------------------
if (Podnosnik_uszkodzony == 0):
    print("Podnosnik jest w szczytowej formie")
    RaportP = 0;

if (Podnosnik_uszkodzony <= 20) and (Podnosnik_uszkodzony>0):
    print("Podnosnik nie wymaga przegladu")
    RaportP = 1;

if (Podnosnik_uszkodzony <= 40) and (Podnosnik_uszkodzony>20):
    print("Podnosnik ma zalecany przeglad")
    RaportP = 2;

if (Podnosnik_uszkodzony <= 60) and (Podnosnik_uszkodzony>40):
    print("Podnosnik wymaga przegladu")
    RaportP = 3;

if (Podnosnik_uszkodzony > 60):
    print("Podnosnik wymaga naprawy")
    RaportP = 4;


#::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# Zapis do Raportu
#::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::

fh = open('raport.txt', 'w')
for i in range(1):
    fh.write('%d \n' % (Przekladnia_uszkodzona))
    fh.write('%d \n' % (Silnik_uszkodzony))
    fh.write('%d \n' % (Czujniki_uszkodzone))

    fh.write('%d \n' % (Utrata_szczelnosci))
    fh.write('%d \n' % (Uszkodzenie_silownika))
    fh.write('%d \n' % (Uszkodzone_sterowanie_lub_lacze))

    fh.write('%d \n' % (Wozek_uszkodzony))
    fh.write('%d \n' % (Podnosnik_uszkodzony))
fh.close()

fh = open('raport_dla_Inzyniera.txt', 'w')
for i in range(1):

    fh.write('\n________________!__Uszkodzone podzespoly__!________________\n')
    fh.write('Poziom uszkodzenia przekladni: %d \n' % (Przekladnia_uszkodzona))
    fh.write('Poziom uszkodzenia silnika: %d \n' % (Silnik_uszkodzony))
    fh.write('Poziom uszkodzenia czujnikow wozka: %d \n' % (Czujniki_uszkodzone))

    fh.write('Poziom utraty szczelnosci: %d \n' % (Utrata_szczelnosci))
    fh.write('Poziom uszkodzenia silownika: %d \n' % (Uszkodzenie_silownika))
    fh.write('Poziom straty na sterowaniu: %d \n' % (Uszkodzone_sterowanie_lub_lacze))
    fh.write('\n\n')
    fh.write('\n__________________Im wyzej tym gorzej__________________\n')
    fh.write('Stan wozka: %d \n' % (Wozek_uszkodzony))
    fh.write('Stan podnosnika: %d \n' % (Podnosnik_uszkodzony))


    fh.write('\n________________!__Sugestie dzialan__!_______________\n')
    if (RaportW == 0) or (RaportW==1):
        fh.write('\n_____Wozek nie potrzebuje dzialan_____\n')
    if (RaportW == 2) or (RaportW==3):
        fh.write('\n_____Wozek potrzebuje dzialan_____\n')
    if (RaportW == 4):
        fh.write('\n_____Wozek wymaga dzialan_____\n')

    if (RaportP == 0) or (RaportP==1):
        fh.write('\n_____Podnosnik nie potrzebuje dzialan_____\n')
    if (RaportP == 2) or (RaportP==3):
        fh.write('\n_____Podnosnik potrzebuje dzialan_____\n')
    if (RaportP == 4):
        fh.write('\n_____Podnosnik wymaga dzialan_____\n')
    fh.write('\n________________!__Miejsce na tabele zmiennych decyzyjnych__!_______________\n')
    fh.write('\n__________________..._________________\n')
    fh.write('\n________________!__Koniec Raportu__!_______________\n')
fh.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-cbeea34071fa> in <module>
#      26   my_list_R = [x.rstrip() for x in f]
#      27 # warunki poczatkowe z poprzedniego raportu
# ---> 28 Przekladnia_uszkodzona_R, Silnik_uszkodzony_R, Czujniki_uszkodzone_R, Utrata_szczelnosci_R, Uszkodzenie_silownika_R, Uszkodzone_sterowanie_lub_lacze_R, Wozek_uszkodzony_R, Podnosnik_uszkodzony_R = my_list_R;
#      29
#      30
#
# ValueError: not enough values to unpack (expected 8, got 0)
